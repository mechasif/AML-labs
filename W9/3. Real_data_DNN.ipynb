# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
print(tf.__version__)
# Out:
# 2.10.1

# %%
def plot_series(time, series, format="-", start = 0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(False)

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(window_size + 1, shift = 1, drop_remainder = True)
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
    dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1:]) )
    dataset = dataset.batch(batch_size).prefetch(1)
    return dataset

# %%
import csv
time_step = []
temperatures = []
with open("daily-min-temperatures.csv") as csvfile:
    reader=csv.reader(csvfile, delimiter = ',')
    next(reader)
    for row in reader:
        temperatures.append(float(row[1]))
series = np.array(temperatures)
#print(series[:100])
series.mean()
# Out:
# 11.177753424657535

# %%
print(series.shape[0])
time = np.arange(series.shape[0])
print(series)
print(time)
# Out:
# 3650
# [20.7 17.9 18.8 ... 13.5 15.7 13. ]
# [   0    1    2 ... 3647 3648 3649]

# %%
plot_series(time,series)

# %%
def model_forecast(model, series, window_size):
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(window_size, shift = 1, drop_remainder = True)
    dataset = dataset.flat_map(lambda w:w.batch(window_size))
    dataset = dataset.batch(32).prefetch(1)
    forecast = model.predict(dataset)
    return forecast

# %%
tf.keras.backend.clear_session()
split_time = 3000
time_train = time[:split_time]
time_valid = time[split_time:]
x_train = series[:split_time]
x_valid = series[split_time:]

window_size = 5
batch_size = 128
shuffle_buffer_size = 1000

# %%
dataset = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters = 128, kernel_size = 3, strides = 1, padding = "causal", activation = "relu", input_shape = [None, 1]),
    tf.keras.layers.LSTM(32, return_sequences=True),
    
    
    tf.keras.layers.Dense(10, activation = "relu"),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x:x*25)])

# %%
model.compile(loss = tf.keras.losses.Huber(), optimizer= tf.keras.optimizers.SGD(learning_rate = 1e-6, momentum = 0.9))

# %%
history = model.fit(dataset, epochs=50, verbose = 1)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 5s 65ms/step - loss: 8.4748
# Epoch 2/50
# 24/24 [==============================] - 1s 16ms/step - loss: 6.9630
# Epoch 3/50
# 24/24 [==============================] - 1s 16ms/step - loss: 4.8156
# Epoch 4/50
# 24/24 [==============================] - 0s 15ms/step - loss: 3.6696
# Epoch 5/50
# 24/24 [==============================] - 0s 15ms/step - loss: 3.4995
# Epoch 6/50
# 24/24 [==============================] - 0s 15ms/step - loss: 3.3832
# Epoch 7/50
# 24/24 [==============================] - 1s 15ms/step - loss: 3.2833
# Epoch 8/50
# 24/24 [==============================] - 0s 15ms/step - loss: 3.1952
# Epoch 9/50
# 24/24 [==============================] - 0s 15ms/step - loss: 3.1162
# Epoch 10/50
# 24/24 [==============================] - 1s 15ms/step - loss: 3.0475
# Epoch 11/50
# 24/24 [==============================] - 1s 15ms/step - loss: 2.9827
# Epoch 12/50
# 24/24 [==============================] - 1s 15ms/step - loss: 2.9259
# Epoch 13/50
# 24/24 [==============================] - 1s 19ms/step - loss: 2.8746
# Epoch 14/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.8267
# Epoch 15/50
# 24/24 [==============================] - 1s 17ms/step - loss: 2.7845
# Epoch 16/50
# 24/24 [==============================] - 1s 18ms/step - loss: 2.7434
# Epoch 17/50
# 24/24 [==============================] - 0s 15ms/step - loss: 2.7058
# Epoch 18/50
# 24/24 [==============================] - 1s 15ms/step - loss: 2.6716
# Epoch 19/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.6379
# Epoch 20/50
# 24/24 [==============================] - 1s 15ms/step - loss: 2.6071
# Epoch 21/50
# 24/24 [==============================] - 1s 18ms/step - loss: 2.5777
# Epoch 22/50
# 24/24 [==============================] - 1s 18ms/step - loss: 2.5506
# Epoch 23/50
# 24/24 [==============================] - 1s 18ms/step - loss: 2.5228
# Epoch 24/50
# 24/24 [==============================] - 1s 19ms/step - loss: 2.4970
# Epoch 25/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.4731
# Epoch 26/50
# 24/24 [==============================] - 1s 19ms/step - loss: 2.4500
# Epoch 27/50
# 24/24 [==============================] - 1s 19ms/step - loss: 2.4283
# Epoch 28/50
# 24/24 [==============================] - 1s 19ms/step - loss: 2.4069
# Epoch 29/50
# 24/24 [==============================] - 1s 21ms/step - loss: 2.3873
# Epoch 30/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.3684
# Epoch 31/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.3497
# Epoch 32/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.3325
# Epoch 33/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.3164
# Epoch 34/50
# 24/24 [==============================] - 1s 17ms/step - loss: 2.3006
# Epoch 35/50
# 24/24 [==============================] - 1s 20ms/step - loss: 2.2864
# Epoch 36/50
# 24/24 [==============================] - 1s 19ms/step - loss: 2.2723
# Epoch 37/50
# 24/24 [==============================] - 1s 19ms/step - loss: 2.2590
# Epoch 38/50
# 24/24 [==============================] - 1s 15ms/step - loss: 2.2467
# Epoch 39/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.2351
# Epoch 40/50
# 24/24 [==============================] - 0s 16ms/step - loss: 2.2244
# Epoch 41/50
# 24/24 [==============================] - 1s 18ms/step - loss: 2.2137
# Epoch 42/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.2044
# Epoch 43/50
# 24/24 [==============================] - 1s 18ms/step - loss: 2.1939
# Epoch 44/50
# 24/24 [==============================] - 1s 20ms/step - loss: 2.1853
# Epoch 45/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.1766
# Epoch 46/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.1686
# Epoch 47/50
# 24/24 [==============================] - 0s 15ms/step - loss: 2.1620
# Epoch 48/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.1538
# Epoch 49/50
# 24/24 [==============================] - 0s 15ms/step - loss: 2.1475
# Epoch 50/50
# 24/24 [==============================] - 1s 16ms/step - loss: 2.1407

# %%
model1_forecast = model_forecast(model, series[..., np.newaxis], window_size)
model1_forecast = model1_forecast[split_time-window_size:-1, -1, 0]
# Out:
# 114/114 [==============================] - 2s 6ms/step

# %%
plt.figure(figsize=(10,7))
plot_series(time_valid, x_valid)
plot_series(time_valid, model1_forecast)

# %%
tf.keras.metrics.mean_absolute_error(x_valid, model1_forecast).numpy()
# Out:
# 1.9817971
